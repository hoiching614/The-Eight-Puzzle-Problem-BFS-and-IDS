# %% [markdown]
# # Assignment 1, 8-Puzzle Programming

# %% [markdown]
# #### Your homework must be implemented in this Notebook file.
# #### You can add as many cells as you want. However, you are not allowed to touch the code below the line "=============".
# #### You need to implement the searching functions and the print result functions. The "print_result() function call after "====" line will print out the results in the format indicated in the Assignment description.
# #### For the searching functions, feel free to customize the return data types and parameter lists as long as the function name is as required.
#
# Write your name, netID and email here.
#
# ### Name: vincent ng
# ### NetID: en7457
# ### Email:vng5@horizon.csueastbay.edu

# %%
# Cases[0] = [8 7 5 4 1 2 3 0 6]
    #875
    #412
    #306
#finalState = [0,1,2,3,4,5,6,7,8]
    #012
    #345
    #678
                       
# valid move
# index 0: down right            , 1 3
# index 1: down right left       , 0 2 4
# index 2: down       left       , 1 5
# index 3: down right      up    , 0 4 6
# index 4: down right left up    , 1 3 5 7 
# index 5: down       left up    , 2 4 8
# index 6:      right      up    , 3 7
# index 7:      right left up    , 4 6 8
# index 8:            left up    , 5 7
########################################################################
# swap index
#def swap(Cases, startPos, endPos):
    #Cases[startPos], Cases[endPos] = Cases[endPos], Cases[startPos]
    #return Cases
#Cases[0] = swap(Cases[0], 5, 8)
#print(Cases[0])
################
########################################################

# %%
#implementation of function "Iterative_deepening_DFS"
finalState = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    #012
    #345
    #678
show_found_final = True# False# 

class Iterative_deepening_DFS:
    def __init__(self, case, parent):
        self.data = case
        self.parent = parent
        self.NodeLeft = None
        self.NodeRight = None
        self.NodeUp = None
        self.NodeDown = None
        
    def check_move_left(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        if index_of_0[0] % 3 == 0: # 0 on the far left
            return False
        else:# have a valid left move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] - 1] = newNode[index_of_0[0] - 1], newNode[index_of_0[0]]
            #print("check_move_left: ", newNode)
            return newNode, True
        
    def check_move_right(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        if index_of_0[0] % 3 == 2: # 0 on the far right
            return False
        else:# have a valid right move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] + 1] = newNode[index_of_0[0] + 1], newNode[index_of_0[0]]
            #print("check_move_right:", newNode)
            return newNode, True
        
    def check_move_up(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        
        if index_of_0[0] < 3: # 0 on the most top
            return False
        else:# have a valid up move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] - 3] = newNode[index_of_0[0] - 3], newNode[index_of_0[0]]
            #print("check_move_up:", newNode)
            return newNode, True
        
    def check_move_down(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        
        if index_of_0[0] > 5: # 0 on the most down
            return False
        else:# have a valid up move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] + 3] = newNode[index_of_0[0] + 3], newNode[index_of_0[0]]
            #print("check_move_Down:", newNode)
            return newNode, True
        
    def display_scenario(self):
        solution = [self.data]
        depth = 0
        
        while self.parent:# get the solution
            self = self.parent
            solution.append(self.data)
            
        print('Solution of the first Scenario(Iterative_deepening_DFS):')
        print(depth, ':')
        #print(solution.pop())
        tamp = solution.pop()
        for i in range(0, 3):
            print('    ', tamp[3*i], tamp[(3*i)+1], tamp[(3*i)+2])
        
        while solution:
            print('      to')
            depth += 1
            print(depth, ':')
            #print(solution.pop())
            tamp = solution.pop()
            for i in range(0, 3):
                print('    ', tamp[3*i], tamp[(3*i)+1], tamp[(3*i)+2])
        
        return depth
        
    def get_depth(self):
        solution = [self.data]
        
        while self.parent:# get the solution
            self = self.parent
            solution.append(self.data)
        
        return len(solution)
        
    def iterative_deepening_DFS_frist(self):
    # Initialize the frontier and exploredList to start expanding
        depth = 0
        while depth < 100:# max depth # 60 too small
            frontier = [self]
            exploredList = set([])
            
            depth_num = [0]
        # start the search
            while frontier:
                current_node = frontier.pop(0)
                exploredList.add(tuple(current_node.data.reshape(1,9)[0]))
                current_depth = depth_num.pop(0)

                if np.array_equal(current_node.data, finalState):
                    if show_found_final:
                        print('\tfind final State')
                    #print('current_node.data: ', current_node.data)
                    return current_node.display_scenario()
                else:
                    if current_depth < depth:
                    # create move left node
                        if current_node.check_move_left():
                            new_current_node, validMove = current_node.check_move_left()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:  
                                current_node.NodeLeft = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeLeft)
                                depth_num.insert(0, current_depth + 1)

                    # create move right node
                        if current_node.check_move_right():
                            new_current_node, validMove = current_node.check_move_right()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeRight = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeRight)
                                depth_num.insert(0, current_depth + 1)

                    # create move up node
                        if current_node.check_move_up():
                            new_current_node, validMove = current_node.check_move_up()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeUp = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeUp)
                                depth_num.insert(0, current_depth + 1)

                    # create move down node
                        if current_node.check_move_down():
                            new_current_node, validMove = current_node.check_move_down()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeDown = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeDown)
                                depth_num.insert(0, current_depth + 1)
            depth += 1
                        
    def iterative_deepening_DFS_after_frist(self):
    # Initialize the frontier and exploredList to start expanding
        depth = 0
        while depth < 100:# max depth # 60 too small
            exploredList = set([])
            frontier= [self]
            depth_num = [0]
        # start the search
            while frontier:
                current_node = frontier.pop(0)
                exploredList.add(tuple(current_node.data.reshape(1,9)[0]))
                current_depth = depth_num.pop(0)

                if np.array_equal(current_node.data, finalState):
                    if show_found_final:
                        print('\tfind final State')
                    #print('current_node.data: ', current_node.data)
                    return current_node.get_depth()
                else:
                    if current_depth < depth:
                    # create move left node
                        if current_node.check_move_left():
                            new_current_node, validMove = current_node.check_move_left()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:  
                                current_node.NodeLeft = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeLeft)
                                depth_num.insert(0, current_depth + 1)

                    # create move right node
                        if current_node.check_move_right():
                            new_current_node, validMove = current_node.check_move_right()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeRight = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeRight)
                                depth_num.insert(0, current_depth + 1)

                    # create move up node
                        if current_node.check_move_up():
                            new_current_node, validMove = current_node.check_move_up()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeUp = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeUp)
                                depth_num.insert(0, current_depth + 1)

                    # create move down node
                        if current_node.check_move_down():
                            new_current_node, validMove = current_node.check_move_down()

                            if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                                current_node.NodeDown = Iterative_deepening_DFS(new_current_node,current_node)
                                frontier.insert(0, current_node.NodeDown)
                                depth_num.insert(0, current_depth + 1)
            depth += 1

# %%
#implementation of function "breadthFirstSearch" 
finalState = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    #012
    #345
    #678
show_found_final = True# False# 
class BreadthFirstSearch:
    def __init__(self, case, parent):
        self.data = case
        self.parent = parent
        self.NodeLeft = None
        self.NodeRight = None
        self.NodeUp = None
        self.NodeDown = None
        
    def check_move_left(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        if index_of_0[0] % 3 == 0: # 0 on the far left
            return False
        else:# have a valid left move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] - 1] = newNode[index_of_0[0] - 1], newNode[index_of_0[0]]
            #print("check_move_left: ", newNode)
            return newNode, True
        
    def check_move_right(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        if index_of_0[0] % 3 == 2: # 0 on the far right
            return False
        else:# have a valid right move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] + 1] = newNode[index_of_0[0] + 1], newNode[index_of_0[0]]
            #print("check_move_right:", newNode)
            return newNode, True
        
    def check_move_up(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        
        if index_of_0[0] < 3: # 0 on the most top
            return False
        else:# have a valid up move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] - 3] = newNode[index_of_0[0] - 3], newNode[index_of_0[0]]
            #print("check_move_up:", newNode)
            return newNode, True
        
    def check_move_down(self):
        # find index of 0 to move it around
        index_of_0 = np.where(self.data == 0)
        
        if index_of_0[0] > 5: # 0 on the most down
            return False
        else:# have a valid up move
            #print(index_of_0[0])
            newNode = self.data.copy() # newNode for after moving
            newNode[index_of_0[0]], newNode[index_of_0[0] + 3] = newNode[index_of_0[0] + 3], newNode[index_of_0[0]]
            #print("check_move_Down:", newNode)
            return newNode, True
        
    def display_scenario(self):
        solution = [self.data]
        depth = 0
        
        while self.parent:# get the solution
            self = self.parent
            solution.append(self.data)
            
        print('Solution of the first Scenario(breadthFirstSearch):')
        print(depth, ':')
        #print(solution.pop())
        tamp = solution.pop()
        for i in range(0, 3):
            print('    ', tamp[3*i], tamp[(3*i)+1], tamp[(3*i)+2])
        
        while solution:
            print('      to')
            depth += 1
            print(depth, ':')
            #print(solution.pop())
            tamp = solution.pop()
            for i in range(0, 3):
                print('    ', tamp[3*i], tamp[(3*i)+1], tamp[(3*i)+2])
        
        return depth
        
    def get_depth(self):
        solution = [self.data]
        
        while self.parent:# get the solution
            self = self.parent
            solution.append(self.data)
        
        return len(solution)
    
    def bfs_frist(self):
    # Initialize the frontier and exploredList to start expanding
        exploredList = set([])
        frontier = [self]
        
    # start the search
        while frontier:
            #print('count: ' ,count)
            
            #print('frontier: ', len(frontier) )
            current_node = frontier.pop(0)
            #print('current_node: ', current_node.data)
            #print('finalState: ', finalState)
            
            exploredList.add(tuple(current_node.data.reshape(1,9)[0]))
            #print('exploredList: ', exploredList )
            
            if np.array_equal(current_node.data, finalState):
                if show_found_final:
                    print("\tFound final state")
                #print('current_node: ', current_node.data)
                step = current_node.display_scenario()
                return step
            else:#np.array_equal(current_node, finalState):
                #print("Not Found final state")
                #return

                # create move left node
                #print('create move left node')
                #validMove, new_current_node = current_node.check_move_left()
                if current_node.check_move_left():
                    new_current_node, validMove = current_node.check_move_left()
                    
                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:  
                        #print('if new_current_node not in frontier:')
                        #print("len(exploredList): ", len(exploredList))
                        #print('new_current_node: ', new_current_node)
                        current_node.NodeLeft = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeLeft)
                        #print('current_node.NodeLeft: ', current_node.NodeLeft.data)
                
                # create move right node
                #print('create move right node')
                if current_node.check_move_right():
                    new_current_node, validMove = current_node.check_move_right()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        #print('new_current_node: ', new_current_node)
                        current_node.NodeRight = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeRight)
                        
                # create move up node
                #print('create move up node')
                if current_node.check_move_up():
                    new_current_node, validMove = current_node.check_move_up()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        #print('new_current_node: ', new_current_node)
                        current_node.NodeUp = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeUp)
                        
                # create move down node
                #print('create move down node')
                if current_node.check_move_down():
                    new_current_node, validMove = current_node.check_move_down()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        #print('new_current_node: ', new_current_node)
                        current_node.NodeDown = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeDown)
                 
                #print('len(exploredList): ', len(exploredList))
                
    def bfs_after_frist(self):
    # Initialize the frontier and exploredList to start expanding
        exploredList = set([])
        frontier = [self]

    # start the search
        while frontier:
            current_node = frontier.pop(0)
            exploredList.add(tuple(current_node.data.reshape(1,9)[0]))
            
            if np.array_equal(current_node.data, finalState):
                if show_found_final:
                    print("\tFound final state")
                #print('current_node: ', current_node.data)
                step = current_node.get_depth()
                return step
            else:
            # create move left node
                if current_node.check_move_left():
                    new_current_node, validMove = current_node.check_move_left()
                    
                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:  
                        current_node.NodeLeft = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeLeft)
                
            # create move right node
                if current_node.check_move_right():
                    new_current_node, validMove = current_node.check_move_right()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        current_node.NodeRight = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeRight)
                        
            # create move up node
                if current_node.check_move_up():
                    new_current_node, validMove = current_node.check_move_up()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        current_node.NodeUp = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeUp)
                        
            # create move down node
                if current_node.check_move_down():
                    new_current_node, validMove = current_node.check_move_down()

                    if tuple(new_current_node.reshape(1,9)[0]) not in exploredList:
                        current_node.NodeDown = BreadthFirstSearch(new_current_node,current_node)
                        frontier.append(current_node.NodeDown)

# %%
#implementation of function "print_result(result)"
import numpy as np   # read file
import time          # timer

def print_result():
    run_iterative_deepening_DFS = True# False# 
    run_breadth_first_search = True# False# 
    limit_run = False# True
    num_example_run = 3 # minimum number run 1
    
# Iterative_deepening_DFS    
    if run_iterative_deepening_DFS:
        # load to example   
        file = open("input8PuzzleCases.txt")
        casses = []
        index = 0
        for line in file:
            s_case=line.strip("\n").split(",")
            casses.append([])

            for i in range (len(s_case)):
                casses[index].append( int(s_case[i]) )

            index += 1   

        #print(type(casses[0]))    

        # varibale for steps and time
        iddfs_steps_list = [] # each case steps
        iddfs_time_list = []  # each case time

        # loop every cases                    
        exampleIndex = 0 # first index#############################################
        example_size = len(casses)

    # first case with display
        print('Iterative_deepening_DFS')
        # start timer
        startTimer = time.time()

        exampleCase = np.array(casses.pop(0))
        print(exampleIndex, 'exampleCase: ', exampleCase)###############################

        rootNode = Iterative_deepening_DFS(exampleCase, None)
        steps = rootNode.iterative_deepening_DFS_frist()

        #time.sleep(4)
        # end timer
        endTimer = time.time()

        # add iddfs time & steps
        iddfs_time_list.append(endTimer-startTimer)
        iddfs_steps_list.append(steps)

        # next example
        exampleIndex+=1;#############################################

    # after first case without display
        if limit_run:
            while exampleIndex < num_example_run:#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                # start timer
                startTimer = time.time()

                exampleCase = np.array(casses.pop(0))
                print(exampleIndex, 'exampleCase: ', exampleCase)##########################

                rootNode = Iterative_deepening_DFS(exampleCase, None)
                steps = rootNode.iterative_deepening_DFS_after_frist()

                #time.sleep(4)
                # end timer
                endTimer = time.time()

                # add iddfs time & steps
                iddfs_time_list.append(endTimer-startTimer)
                iddfs_steps_list.append(steps)

                # next example
                exampleIndex+=1;#############################################
        else:
            while exampleIndex < example_size:#############################################
                # start timer
                startTimer = time.time()

                exampleCase = np.array(casses.pop(0))
                print(exampleIndex, 'exampleCase: ', exampleCase)##########################

                rootNode = Iterative_deepening_DFS(exampleCase, None)
                steps = rootNode.iterative_deepening_DFS_after_frist()

                #time.sleep(4)
                # end timer
                endTimer = time.time()

                # add iddfs time & steps
                iddfs_time_list.append(endTimer-startTimer)
                iddfs_steps_list.append(steps)

                # next example
                exampleIndex+=1;#############################################
        
#////////////////////////////////////////////////////////////////////////////////////////////////
# breadthFirstSearch
    if run_breadth_first_search:
        # load to example   
        file = open("input8PuzzleCases.txt")
        casses = []
        index = 0
        for line in file:
            s_case=line.strip("\n").split(",")
            casses.append([])

            for i in range (len(s_case)):
                casses[index].append( int(s_case[i]) )

            index += 1   

        #print(type(casses[0]))

        # varibale for steps and time
        bfs_steps_list = [] # each case steps
        bfs_time_list = []  # each case time

        # loop every cases                    
        exampleIndex = 0 # first index####################################
        example_size = len(casses)
        
    # first case with display
        print('breadthFirstSearch')
        # start timer
        startTimer = time.time()

        exampleCase = np.array(casses.pop(0))
        print(exampleIndex, 'exampleCase: ', exampleCase)

        rootNode = BreadthFirstSearch(exampleCase, None)
        steps = rootNode.bfs_frist()

        #time.sleep(4)
        # end timer
        endTimer = time.time()

        # add BFS time & steps
        bfs_time_list.append(endTimer-startTimer)
        bfs_steps_list.append(steps)

        # next example
        exampleIndex+=1;############################################################

    # after first case without display
        if limit_run:
            while exampleIndex < num_example_run:#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                # start timer
                startTimer = time.time()

                exampleCase = np.array(casses.pop(0))
                print(exampleIndex, 'exampleCase: ', exampleCase)#######################

                rootNode = BreadthFirstSearch(exampleCase, None)
                steps = rootNode.bfs_after_frist()

                #time.sleep(4)
                # end timer
                endTimer = time.time()

                # add BFS time & steps
                bfs_time_list.append(endTimer-startTimer)
                bfs_steps_list.append(steps)

                exampleIndex+=1;############################################################
        else:
            while exampleIndex < example_size:############################################
                # start timer
                startTimer = time.time()

                exampleCase = np.array(casses.pop(0))
                print(exampleIndex, 'exampleCase: ', exampleCase)#######################

                rootNode = BreadthFirstSearch(exampleCase, None)
                steps = rootNode.bfs_after_frist()

                #time.sleep(4)
                # end timer
                endTimer = time.time()

                # add BFS time & steps
                bfs_time_list.append(endTimer-startTimer)
                bfs_steps_list.append(steps)

                exampleIndex+=1;############################################################
#//////////////////////////////////////////////////////////////////        
# get average steps & time      
    # Iterative_deepening_DFS
    if run_iterative_deepening_DFS:
        iddfs_average_steps = sum(iddfs_steps_list)
        iddfs_average_steps = iddfs_average_steps/len(iddfs_steps_list)

        iddfs_average_time = sum(iddfs_time_list)
        iddfs_average_time = iddfs_average_time/len(iddfs_time_list)

        #print('Iterative_deepening_DFS')
        #print('number of cases: ', len(iddfs_steps_list) )
        #print('1 cases: \tsteps: ', iddfs_steps_list[0], '\ttime: ', iddfs_time_list[0])
        #print('2 cases: \tsteps: ', iddfs_steps_list[1], '\ttime: ', iddfs_time_list[1])

    # BFS
    if run_breadth_first_search:
        bfs_average_steps = sum(bfs_steps_list)
        bfs_average_steps = bfs_average_steps/len(bfs_steps_list)

        bfs_average_time = sum(bfs_time_list)
        bfs_average_time = bfs_average_time/len(bfs_time_list)

        #print('breadthFirstSearch')
        #print('number of cases: ', len(bfs_steps_list) )
        #print('1 cases: \tsteps: ', bfs_steps_list[0], '\ttime: ', bfs_time_list[0])
        #print('2 cases: \tsteps: ', bfs_steps_list[1], '\ttime: ', bfs_time_list[1])

# display
    print('\t\tAverage_Steps\tAverage_Time')
    if run_iterative_deepening_DFS:
        print('IDS\t\t  ', iddfs_average_steps , '      \t', "{:.2f}".format(iddfs_average_time) )
    if run_breadth_first_search:
        print('BFS\t\t  ', bfs_average_steps , '      \t', "{:.2f}".format(bfs_average_time) )  

############################################################
print_result()
# Out:
# Iterative_deepening_DFS
# 0 exampleCase:  [8 7 5 4 1 2 3 0 6]
# 	find final State
# Solution of the first Scenario(Iterative_deepening_DFS):
# 0 :
#      8 7 5
#      4 1 2
#      3 0 6
#       to
# 1 :
#      8 7 5
#      4 0 2
#      3 1 6
#       to
# 2 :
#      8 0 5
#      4 7 2
#      3 1 6
#       to
# 3 :
#      0 8 5
#      4 7 2
#      3 1 6
#       to
# 4 :
#      4 8 5
#      0 7 2
#      3 1 6
#       to
# 5 :
#      4 8 5
#      3 7 2
#      0 1 6
#       to
# 6 :
#      4 8 5
#      3 7 2
#      1 0 6
#       to
# 7 :
#      4 8 5
#      3 0 2
#      1 7 6
#       to
# 8 :
#      4 8 5
#      0 3 2
#      1 7 6
#       to
# 9 :
#      4 8 5
#      1 3 2
#      0 7 6
#       to
# 10 :
#      4 8 5
#      1 3 2
#      7 0 6
#       to
# 11 :
#      4 8 5
#      1 0 2
#      7 3 6
#       to
# 12 :
#      4 8 5
#      1 2 0
#      7 3 6
#       to
# 13 :
#      4 8 0
#      1 2 5
#      7 3 6
#       to
# 14 :
#      4 0 8
#      1 2 5
#      7 3 6
#       to
# 15 :
#      4 2 8
#      1 0 5
#      7 3 6
#       to
# 16 :
#      4 2 8
#      1 5 0
#      7 3 6
#       to
# 17 :
#      4 2 0
#      1 5 8
#      7 3 6
#       to
# 18 :
#      4 0 2
#      1 5 8
#      7 3 6
#       to
# 19 :
#      0 4 2
#      1 5 8
#      7 3 6
#       to
# 20 :
#      1 4 2
#      0 5 8
#      7 3 6
#       to
# 21 :
#      1 4 2
#      7 5 8
#      0 3 6
#       to
# 22 :
#      1 4 2
#      7 5 8
#      3 0 6
#       to
# 23 :
#      1 4 2
#      7 5 8
#      3 6 0
#       to
# 24 :
#      1 4 2
#      7 5 0
#      3 6 8
#       to
# 25 :
#      1 4 2
#      7 0 5
#      3 6 8
#       to
# 26 :
#      1 0 2
#      7 4 5
#      3 6 8
#       to
# 27 :
#      1 2 0
#      7 4 5
#      3 6 8
#       to
# 28 :
#      1 2 5
#      7 4 0
#      3 6 8
#       to
# 29 :
#      1 2 5
#      7 0 4
#      3 6 8
#       to
# 30 :
#      1 2 5
#      0 7 4
#      3 6 8
#       to
# 31 :
#      1 2 5
#      3 7 4
#      0 6 8
#       to
# 32 :
#      1 2 5
#      3 7 4
#      6 0 8
#       to
# 33 :
#      1 2 5
#      3 0 4
#      6 7 8
#       to
# 34 :
#      1 2 5
#      3 4 0
#      6 7 8
#       to
# 35 :
#      1 2 0
#      3 4 5
#      6 7 8
#       to
# 36 :
#      1 0 2
#      3 4 5
#      6 7 8
#       to
# 37 :
#      0 1 2
#      3 4 5
#      6 7 8
# 1 exampleCase:  [7 8 6 0 2 5 1 4 3]
# 	find final State
# 2 exampleCase:  [1 0 7 5 3 6 8 4 2]
# 	find final State
# 3 exampleCase:  [3 8 4 0 1 7 5 2 6]
# 	find final State
# 4 exampleCase:  [6 1 2 7 0 8 5 4 3]
# 	find final State
# 5 exampleCase:  [2 5 3 1 4 6 8 0 7]
# 	find final State
# 6 exampleCase:  [6 8 5 3 4 7 2 1 0]
# 	find final State
# 7 exampleCase:  [2 7 8 0 1 5 4 3 6]
# 	find final State
# 8 exampleCase:  [6 5 2 1 4 8 0 7 3]
# 	find final State
# 9 exampleCase:  [0 6 1 3 4 7 8 5 2]
# 	find final State
# 10 exampleCase:  [8 5 1 7 3 2 4 6 0]
# 	find final State
# 11 exampleCase:  [4 2 7 1 5 0 8 6 3]
# 	find final State
# 12 exampleCase:  [2 7 5 8 4 6 3 0 1]
# 	find final State
# 13 exampleCase:  [6 5 8 0 2 1 7 4 3]
# 	find final State
# 14 exampleCase:  [8 5 6 2 7 0 1 4 3]
# 	find final State
# 15 exampleCase:  [2 0 7 5 1 8 6 3 4]
# 	find final State
# 16 exampleCase:  [4 2 5 7 3 1 6 8 0]
# 	find final State
# 17 exampleCase:  [7 2 0 1 3 4 6 5 8]
# 	find final State
# 18 exampleCase:  [2 6 8 7 5 0 3 1 4]
# 	find final State
# 19 exampleCase:  [1 5 0 4 7 2 6 8 3]
# 	find final State
# 20 exampleCase:  [6 5 3 8 4 7 2 1 0]
# 	find final State
# 21 exampleCase:  [8 2 4 0 3 5 6 7 1]
# 	find final State
# 22 exampleCase:  [5 4 2 8 3 6 0 1 7]
# 	find final State
# 23 exampleCase:  [4 0 5 8 7 2 3 6 1]
# 	find final State
# 24 exampleCase:  [6 0 1 4 7 3 5 2 8]
# 	find final State
# 25 exampleCase:  [4 5 3 1 0 6 7 2 8]
# 	find final State
# 26 exampleCase:  [1 0 8 5 3 7 6 4 2]
# 	find final State
# 27 exampleCase:  [4 2 6 3 7 0 8 1 5]
# 	find final State
# 28 exampleCase:  [8 4 5 7 1 3 2 6 0]
# 	find final State
# 29 exampleCase:  [1 5 7 4 0 8 2 3 6]
# 	find final State
# 30 exampleCase:  [5 7 0 6 3 8 1 2 4]
# 	find final State
# 31 exampleCase:  [2 3 1 6 7 0 5 8 4]
# 	find final State
# 32 exampleCase:  [1 6 3 0 4 5 7 2 8]
# 	find final State
# 33 exampleCase:  [8 0 3 4 6 1 2 5 7]
# 	find final State
# 34 exampleCase:  [6 2 4 8 5 7 0 1 3]
# 	find final State
# 35 exampleCase:  [4 7 0 8 2 5 3 6 1]
# 	find final State
# 36 exampleCase:  [3 6 1 7 8 0 5 2 4]
# 	find final State
# 37 exampleCase:  [1 3 4 5 2 6 8 7 0]
# 	find final State
# 38 exampleCase:  [1 0 6 2 4 5 7 8 3]
# 	find final State
# 39 exampleCase:  [0 5 4 2 6 1 8 3 7]
# 	find final State
# 40 exampleCase:  [8 4 6 3 2 7 5 0 1]
# 	find final State
# 41 exampleCase:  [3 6 8 4 2 7 1 5 0]
# 	find final State
# 42 exampleCase:  [0 6 2 7 1 5 3 4 8]
# 	find final State
# 43 exampleCase:  [3 5 6 0 1 4 2 8 7]
# 	find final State
# 44 exampleCase:  [4 0 7 3 6 2 1 5 8]
# 	find final State
# 45 exampleCase:  [1 6 4 2 8 3 0 7 5]
# 	find final State
# 46 exampleCase:  [6 0 1 3 2 7 4 5 8]
# 	find final State
# 47 exampleCase:  [3 5 0 6 7 8 2 4 1]
# 	find final State
# 48 exampleCase:  [2 0 5 4 7 3 6 8 1]
# 	find final State
# 49 exampleCase:  [7 2 0 4 1 6 5 3 8]
# 	find final State
# 50 exampleCase:  [6 4 8 1 3 7 2 5 0]
# 	find final State
# 51 exampleCase:  [8 3 6 5 0 2 1 7 4]
# 	find final State
# 52 exampleCase:  [6 2 5 8 1 3 7 4 0]
# 	find final State
# 53 exampleCase:  [4 3 2 0 5 8 1 6 7]
# 	find final State
# 54 exampleCase:  [5 1 4 0 3 7 2 8 6]
# 	find final State
# 55 exampleCase:  [3 8 5 4 1 7 0 6 2]
# 	find final State
# 56 exampleCase:  [8 4 2 6 1 0 7 3 5]
# 	find final State
# 57 exampleCase:  [5 1 6 4 2 8 7 0 3]
# 	find final State
# 58 exampleCase:  [4 6 5 3 8 7 2 0 1]
# 	find final State
# 59 exampleCase:  [1 3 2 8 6 0 4 7 5]
# 	find final State
# 60 exampleCase:  [7 8 3 2 0 1 5 4 6]
# 	find final State
# 61 exampleCase:  [5 2 4 8 1 6 3 0 7]
# 	find final State
# 62 exampleCase:  [0 4 3 1 2 5 7 6 8]
# 	find final State
# 63 exampleCase:  [3 5 0 7 4 1 2 8 6]
# 	find final State
# 64 exampleCase:  [4 7 0 5 6 1 2 3 8]
# 	find final State
# 65 exampleCase:  [3 5 1 4 6 2 0 8 7]
# 	find final State
# 66 exampleCase:  [0 8 6 4 3 7 1 2 5]
# 	find final State
# 67 exampleCase:  [7 4 0 2 5 8 6 3 1]
# 	find final State
# 68 exampleCase:  [0 3 5 8 4 2 7 6 1]
# 	find final State
# 69 exampleCase:  [2 4 6 0 3 7 5 1 8]
# 	find final State
# 70 exampleCase:  [6 4 7 1 3 2 8 5 0]
# 	find final State
# 71 exampleCase:  [1 8 5 2 0 6 3 7 4]
# 	find final State
# 72 exampleCase:  [6 8 5 2 4 3 7 1 0]
# 	find final State
# 73 exampleCase:  [2 4 3 7 1 8 6 5 0]
# 	find final State
# 74 exampleCase:  [5 2 3 0 4 7 6 1 8]
# 	find final State
# 75 exampleCase:  [3 4 5 6 7 2 0 8 1]
# 	find final State
# 76 exampleCase:  [4 6 5 2 7 8 0 3 1]
# 	find final State
# 77 exampleCase:  [5 1 8 6 4 0 7 2 3]
# 	find final State
# 78 exampleCase:  [1 2 3 5 4 0 6 8 7]
# 	find final State
# 79 exampleCase:  [2 0 6 7 8 4 5 3 1]
# 	find final State
# 80 exampleCase:  [7 2 8 4 6 0 3 1 5]
# 	find final State
# 81 exampleCase:  [7 0 6 4 1 2 8 3 5]
# 	find final State
# 82 exampleCase:  [3 5 4 7 0 6 1 2 8]
# 	find final State
# 83 exampleCase:  [8 2 7 0 6 5 4 1 3]
# 	find final State
# 84 exampleCase:  [0 5 1 4 3 2 8 7 6]
# 	find final State
# 85 exampleCase:  [4 1 8 7 5 0 3 6 2]
# 	find final State
# 86 exampleCase:  [2 3 4 6 5 8 1 0 7]
# 	find final State
# 87 exampleCase:  [8 2 6 1 0 5 7 3 4]
# 	find final State
# 88 exampleCase:  [5 4 2 0 8 1 7 3 6]
# 	find final State
# 89 exampleCase:  [4 8 2 0 5 1 7 3 6]
# 	find final State
# 90 exampleCase:  [2 1 3 0 7 8 6 5 4]
# 	find final State
# 91 exampleCase:  [8 6 4 0 3 5 2 1 7]
# 	find final State
# 92 exampleCase:  [8 3 7 4 2 6 5 0 1]
# 	find final State
# 93 exampleCase:  [6 7 2 4 1 5 0 3 8]
# 	find final State
# 94 exampleCase:  [7 4 1 5 3 2 6 8 0]
# 	find final State
# 95 exampleCase:  [8 0 2 4 5 1 3 6 7]
# 	find final State
# 96 exampleCase:  [1 2 4 5 3 6 7 0 8]
# 	find final State
# 97 exampleCase:  [6 5 1 0 8 3 4 7 2]
# 	find final State
# 98 exampleCase:  [7 5 8 3 4 1 0 6 2]
# 	find final State
# 99 exampleCase:  [6 5 7 3 8 0 4 1 2]
# 	find final State
# breadthFirstSearch
# 0 exampleCase:  [8 7 5 4 1 2 3 0 6]
# 	Found final state
# Solution of the first Scenario(breadthFirstSearch):
# 0 :
#      8 7 5
#      4 1 2
#      3 0 6
#       to
# 1 :
#      8 7 5
#      4 0 2
#      3 1 6
#       to
# 2 :
#      8 7 5
#      4 2 0
#      3 1 6
#       to
# 3 :
#      8 7 0
#      4 2 5
#      3 1 6
#       to
# 4 :
#      8 0 7
#      4 2 5
#      3 1 6
#       to
# 5 :
#      8 2 7
#      4 0 5
#      3 1 6
#       to
# 6 :
#      8 2 7
#      4 1 5
#      3 0 6
#       to
# 7 :
#      8 2 7
#      4 1 5
#      3 6 0
#       to
# 8 :
#      8 2 7
#      4 1 0
#      3 6 5
#       to
# 9 :
#      8 2 0
#      4 1 7
#      3 6 5
#       to
# 10 :
#      8 0 2
#      4 1 7
#      3 6 5
#       to
# 11 :
#      0 8 2
#      4 1 7
#      3 6 5
#       to
# 12 :
#      4 8 2
#      0 1 7
#      3 6 5
#       to
# 13 :
#      4 8 2
#      1 0 7
#      3 6 5
#       to
# 14 :
#      4 0 2
#      1 8 7
#      3 6 5
#       to
# 15 :
#      0 4 2
#      1 8 7
#      3 6 5
#       to
# 16 :
#      1 4 2
#      0 8 7
#      3 6 5
#       to
# 17 :
#      1 4 2
#      3 8 7
#      0 6 5
#       to
# 18 :
#      1 4 2
#      3 8 7
#      6 0 5
#       to
# 19 :
#      1 4 2
#      3 0 7
#      6 8 5
#       to
# 20 :
#      1 4 2
#      3 7 0
#      6 8 5
#       to
# 21 :
#      1 4 2
#      3 7 5
#      6 8 0
#       to
# 22 :
#      1 4 2
#      3 7 5
#      6 0 8
#       to
# 23 :
#      1 4 2
#      3 0 5
#      6 7 8
#       to
# 24 :
#      1 0 2
#      3 4 5
#      6 7 8
#       to
# 25 :
#      0 1 2
#      3 4 5
#      6 7 8
# 1 exampleCase:  [7 8 6 0 2 5 1 4 3]
# 	Found final state
# 2 exampleCase:  [1 0 7 5 3 6 8 4 2]
# 	Found final state
# 3 exampleCase:  [3 8 4 0 1 7 5 2 6]
# 	Found final state
# 4 exampleCase:  [6 1 2 7 0 8 5 4 3]
# 	Found final state
# 5 exampleCase:  [2 5 3 1 4 6 8 0 7]
# 	Found final state
# 6 exampleCase:  [6 8 5 3 4 7 2 1 0]
# 	Found final state
# 7 exampleCase:  [2 7 8 0 1 5 4 3 6]
# 	Found final state
# 8 exampleCase:  [6 5 2 1 4 8 0 7 3]
# 	Found final state
# 9 exampleCase:  [0 6 1 3 4 7 8 5 2]
# 	Found final state
# 10 exampleCase:  [8 5 1 7 3 2 4 6 0]
# 	Found final state
# 11 exampleCase:  [4 2 7 1 5 0 8 6 3]
# 	Found final state
# 12 exampleCase:  [2 7 5 8 4 6 3 0 1]
# 	Found final state
# 13 exampleCase:  [6 5 8 0 2 1 7 4 3]
# 	Found final state
# 14 exampleCase:  [8 5 6 2 7 0 1 4 3]
# 	Found final state
# 15 exampleCase:  [2 0 7 5 1 8 6 3 4]
# 	Found final state
# 16 exampleCase:  [4 2 5 7 3 1 6 8 0]
# 	Found final state
# 17 exampleCase:  [7 2 0 1 3 4 6 5 8]
# 	Found final state
# 18 exampleCase:  [2 6 8 7 5 0 3 1 4]
# 	Found final state
# 19 exampleCase:  [1 5 0 4 7 2 6 8 3]
# 	Found final state
# 20 exampleCase:  [6 5 3 8 4 7 2 1 0]
# 	Found final state
# 21 exampleCase:  [8 2 4 0 3 5 6 7 1]
# 	Found final state
# 22 exampleCase:  [5 4 2 8 3 6 0 1 7]
# 	Found final state
# 23 exampleCase:  [4 0 5 8 7 2 3 6 1]
# 	Found final state
# 24 exampleCase:  [6 0 1 4 7 3 5 2 8]
# 	Found final state
# 25 exampleCase:  [4 5 3 1 0 6 7 2 8]
# 	Found final state
# 26 exampleCase:  [1 0 8 5 3 7 6 4 2]
# 	Found final state
# 27 exampleCase:  [4 2 6 3 7 0 8 1 5]
# 	Found final state
# 28 exampleCase:  [8 4 5 7 1 3 2 6 0]
# 	Found final state
# 29 exampleCase:  [1 5 7 4 0 8 2 3 6]
# 	Found final state
# 30 exampleCase:  [5 7 0 6 3 8 1 2 4]
# 	Found final state
# 31 exampleCase:  [2 3 1 6 7 0 5 8 4]
# 	Found final state
# 32 exampleCase:  [1 6 3 0 4 5 7 2 8]
# 	Found final state
# 33 exampleCase:  [8 0 3 4 6 1 2 5 7]
# 	Found final state
# 34 exampleCase:  [6 2 4 8 5 7 0 1 3]
# 	Found final state
# 35 exampleCase:  [4 7 0 8 2 5 3 6 1]
# 	Found final state
# 36 exampleCase:  [3 6 1 7 8 0 5 2 4]
# 	Found final state
# 37 exampleCase:  [1 3 4 5 2 6 8 7 0]
# 	Found final state
# 38 exampleCase:  [1 0 6 2 4 5 7 8 3]
# 	Found final state
# 39 exampleCase:  [0 5 4 2 6 1 8 3 7]
# 	Found final state
# 40 exampleCase:  [8 4 6 3 2 7 5 0 1]
# 	Found final state
# 41 exampleCase:  [3 6 8 4 2 7 1 5 0]
# 	Found final state
# 42 exampleCase:  [0 6 2 7 1 5 3 4 8]
# 	Found final state
# 43 exampleCase:  [3 5 6 0 1 4 2 8 7]
# 	Found final state
# 44 exampleCase:  [4 0 7 3 6 2 1 5 8]
# 	Found final state
# 45 exampleCase:  [1 6 4 2 8 3 0 7 5]
# 	Found final state
# 46 exampleCase:  [6 0 1 3 2 7 4 5 8]
# 	Found final state
# 47 exampleCase:  [3 5 0 6 7 8 2 4 1]
# 	Found final state
# 48 exampleCase:  [2 0 5 4 7 3 6 8 1]
# 	Found final state
# 49 exampleCase:  [7 2 0 4 1 6 5 3 8]
# 	Found final state
# 50 exampleCase:  [6 4 8 1 3 7 2 5 0]
# 	Found final state
# 51 exampleCase:  [8 3 6 5 0 2 1 7 4]
# 	Found final state
# 52 exampleCase:  [6 2 5 8 1 3 7 4 0]
# 	Found final state
# 53 exampleCase:  [4 3 2 0 5 8 1 6 7]
# 	Found final state
# 54 exampleCase:  [5 1 4 0 3 7 2 8 6]
# 	Found final state
# 55 exampleCase:  [3 8 5 4 1 7 0 6 2]
# 	Found final state
# 56 exampleCase:  [8 4 2 6 1 0 7 3 5]
# 	Found final state
# 57 exampleCase:  [5 1 6 4 2 8 7 0 3]
# 	Found final state
# 58 exampleCase:  [4 6 5 3 8 7 2 0 1]
# 	Found final state
# 59 exampleCase:  [1 3 2 8 6 0 4 7 5]
# 	Found final state
# 60 exampleCase:  [7 8 3 2 0 1 5 4 6]
# 	Found final state
# 61 exampleCase:  [5 2 4 8 1 6 3 0 7]
# 	Found final state
# 62 exampleCase:  [0 4 3 1 2 5 7 6 8]
# 	Found final state
# 63 exampleCase:  [3 5 0 7 4 1 2 8 6]
# 	Found final state
# 64 exampleCase:  [4 7 0 5 6 1 2 3 8]
# 	Found final state
# 65 exampleCase:  [3 5 1 4 6 2 0 8 7]
# 	Found final state
# 66 exampleCase:  [0 8 6 4 3 7 1 2 5]
# 	Found final state
# 67 exampleCase:  [7 4 0 2 5 8 6 3 1]
# 	Found final state
# 68 exampleCase:  [0 3 5 8 4 2 7 6 1]
# 	Found final state
# 69 exampleCase:  [2 4 6 0 3 7 5 1 8]
# 	Found final state
# 70 exampleCase:  [6 4 7 1 3 2 8 5 0]
# 	Found final state
# 71 exampleCase:  [1 8 5 2 0 6 3 7 4]
# 	Found final state
# 72 exampleCase:  [6 8 5 2 4 3 7 1 0]
# 	Found final state
# 73 exampleCase:  [2 4 3 7 1 8 6 5 0]
# 	Found final state
# 74 exampleCase:  [5 2 3 0 4 7 6 1 8]
# 	Found final state
# 75 exampleCase:  [3 4 5 6 7 2 0 8 1]
# 	Found final state
# 76 exampleCase:  [4 6 5 2 7 8 0 3 1]
# 	Found final state
# 77 exampleCase:  [5 1 8 6 4 0 7 2 3]
# 	Found final state
# 78 exampleCase:  [1 2 3 5 4 0 6 8 7]
# 	Found final state
# 79 exampleCase:  [2 0 6 7 8 4 5 3 1]
# 	Found final state
# 80 exampleCase:  [7 2 8 4 6 0 3 1 5]
# 	Found final state
# 81 exampleCase:  [7 0 6 4 1 2 8 3 5]
# 	Found final state
# 82 exampleCase:  [3 5 4 7 0 6 1 2 8]
# 	Found final state
# 83 exampleCase:  [8 2 7 0 6 5 4 1 3]
# 	Found final state
# 84 exampleCase:  [0 5 1 4 3 2 8 7 6]
# 	Found final state
# 85 exampleCase:  [4 1 8 7 5 0 3 6 2]
# 	Found final state
# 86 exampleCase:  [2 3 4 6 5 8 1 0 7]
# 	Found final state
# 87 exampleCase:  [8 2 6 1 0 5 7 3 4]
# 	Found final state
# 88 exampleCase:  [5 4 2 0 8 1 7 3 6]
# 	Found final state
# 89 exampleCase:  [4 8 2 0 5 1 7 3 6]
# 	Found final state
# 90 exampleCase:  [2 1 3 0 7 8 6 5 4]
# 	Found final state
# 91 exampleCase:  [8 6 4 0 3 5 2 1 7]
# 	Found final state
# 92 exampleCase:  [8 3 7 4 2 6 5 0 1]
# 	Found final state
# 93 exampleCase:  [6 7 2 4 1 5 0 3 8]
# 	Found final state
# 94 exampleCase:  [7 4 1 5 3 2 6 8 0]
# 	Found final state
# 95 exampleCase:  [8 0 2 4 5 1 3 6 7]
# 	Found final state
# 96 exampleCase:  [1 2 4 5 3 6 7 0 8]
# 	Found final state
# 97 exampleCase:  [6 5 1 0 8 3 4 7 2]
# 	Found final state
# 98 exampleCase:  [7 5 8 3 4 1 0 6 2]
# 	Found final state
# 99 exampleCase:  [6 5 7 3 8 0 4 1 2]
# 	Found final state
# 		Average_Steps	Average_Time
# IDS		   29.68       	 21.64
# BFS		   23.32       	 21.07

# %%
29.68 21.64
23.32 21.07

# %% [markdown]
# ## You can insert as many cells as you want above
# ## You are not Allowed to modify the code below this line.
#
# # ============================================================

# %%
#you need to implement print_result function to print out the result according to the required format
print_result()

# %% [markdown]
# # The output format should be as follows. You only need to give one sample solution as an example.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Solution of the first Scenario:
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### .
# #### .
# #### .
# #### 0 1 2
# #### 3 4 5
# #### 6 7 8
#
#                 Average_Steps    Average_Time
#  IDS
#
#  BFS
